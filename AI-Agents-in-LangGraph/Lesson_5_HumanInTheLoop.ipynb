# %% [markdown]
# # Lesson 5: Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
from uuid import uuid4
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage

"""
In previous examples we've annotated the `messages` state key
with the default `operator.add` or `+` reducer, which always
appends new messages to the end of the existing messages array.

Now, to support replacing existing messages, we annotate the
`messages` key with a customer reducer function, which replaces
messages with the same `id`, and appends them otherwise.
"""
def reduce_messages(left: list[AnyMessage], right: list[AnyMessage]) -> list[AnyMessage]:
    # assign ids to messages that don't have them
    for message in right:
        if not message.id:
            message.id = str(uuid4())
    # merge the new messages with the existing messages
    merged = left.copy()
    for message in right:
        for i, existing in enumerate(merged):
            # replace any existing messages with the same id
            if existing.id == message.id:
                merged[i] = message
                break
        else:
            # append any new messages to the end
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], reduce_messages]

# %%
tool = TavilySearchResults(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"]  # adding intrupt, so that user can made final decision.
        )
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-3.5-turbo")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in SF?', id='570a4393-0f8f-4b74-9419-6d09d030f6ab'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-691ea288-06b9-4ff2-b95b-0c68d1a83370-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-691ea288-06b9-4ff2-b95b-0c68d1a83370-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', id='570a4393-0f8f-4b74-9419-6d09d030f6ab'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-691ea288-06b9-4ff2-b95b-0c68d1a83370-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}, next=('action',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f3-6c34-6f58-8001-6d044cc538e4'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-691ea288-06b9-4ff2-b95b-0c68d1a83370-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}}}, created_at='2026-05-14T04:41:46.497600+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f3-6b4f-61ee-8000-9949a820f354'}})

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 for event in abot.graph.stream(None, thread):
#       2     for v in event.values():
#       3         print(v)
#
# File /usr/local/lib/python3.11/site-packages/langgraph/pregel/__init__.py:839, in Pregel.stream(self, input, config, stream_mode, output_keys, input_keys, interrupt_before, interrupt_after, debug)
#     832 done, inflight = concurrent.futures.wait(
#     833     futures,
#     834     return_when=concurrent.futures.FIRST_EXCEPTION,
#     835     timeout=self.step_timeout,
#     836 )
#     838 # panic on failure or timeout
# --> 839 _panic_or_proceed(done, inflight, step)
#     841 # combine pending writes from all tasks
#     842 pending_writes = deque[tuple[str, Any]]()
#
# File /usr/local/lib/python3.11/site-packages/langgraph/pregel/__init__.py:1342, in _panic_or_proceed(done, inflight, step)
#    1340             inflight.pop().cancel()
#    1341         # raise the exception
# -> 1342         raise exc
#    1344 if inflight:
#    1345     # if we got here means we timed out
#    1346     while inflight:
#    1347         # cancel all pending tasks
#
# File /usr/local/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /usr/local/lib/python3.11/site-packages/langgraph/pregel/retry.py:66, in run_with_retry(task, retry_policy)
#      64 task.writes.clear()
#      65 # run the task
# ---> 66 task.proc.invoke(task.input, task.config)
#      67 # if successful, end
#      68 break
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/runnables/base.py:2368, in RunnableSequence.invoke(self, input, config)
#    2366 try:
#    2367     for i, step in enumerate(self.steps):
# -> 2368         input = step.invoke(
#    2369             input,
#    2370             # mark each step as a child run
#    2371             patch_config(
#    2372                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2373             ),
#    2374         )
#    2375 # finish the root run
#    2376 except BaseException as e:
#
# File /usr/local/lib/python3.11/site-packages/langgraph/utils.py:89, in RunnableCallable.invoke(self, input, config)
#      83     context.run(var_child_runnable_config.set, config)
#      84     kwargs = (
#      85         {**self.kwargs, "config": config}
#      86         if accepts_config(self.func)
#      87         else self.kwargs
#      88     )
# ---> 89     ret = context.run(self.func, input, **kwargs)
#      90 if isinstance(ret, Runnable) and self.recurse:
#      91     return ret.invoke(input, config)
#
# Cell In[7], line 21, in Agent.call_openai(self, state)
#      19 if self.system:
#      20     messages = [SystemMessage(content=self.system)] + messages
# ---> 21 message = self.model.invoke(messages)
#      22 return {'messages': [message]}
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/runnables/base.py:4396, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4390 def invoke(
#    4391     self,
#    4392     input: Input,
#    4393     config: Optional[RunnableConfig] = None,
#    4394     **kwargs: Optional[Any],
#    4395 ) -> Output:
# -> 4396     return self.bound.invoke(
#    4397         input,
#    4398         self._merge_configs(config),
#    4399         **{**self.kwargs, **kwargs},
#    4400     )
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:170, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     159 def invoke(
#     160     self,
#     161     input: LanguageModelInput,
#    (...)
#     165     **kwargs: Any,
#     166 ) -> BaseMessage:
#     167     config = ensure_config(config)
#     168     return cast(
#     169         ChatGeneration,
# --> 170         self.generate_prompt(
#     171             [self._convert_input(input)],
#     172             stop=stop,
#     173             callbacks=config.get("callbacks"),
#     174             tags=config.get("tags"),
#     175             metadata=config.get("metadata"),
#     176             run_name=config.get("run_name"),
#     177             run_id=config.pop("run_id", None),
#     178             **kwargs,
#     179         ).generations[0][0],
#     180     ).message
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:671, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     669 else:
#     670     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 671         result = self._generate(
#     672             messages, stop=stop, run_manager=run_manager, **kwargs
#     673         )
#     674     else:
#     675         result = self._generate(messages, stop=stop, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:522, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     520 message_dicts, params = self._create_message_dicts(messages, stop)
#     521 params = {**params, **kwargs}
# --> 522 response = self.client.create(messages=message_dicts, **params)
#     523 return self._create_chat_result(response)
#
# File /usr/local/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/openai/resources/chat/completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File /usr/local/lib/python3.11/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/lib/python3.11/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File /usr/local/lib/python3.11/site-packages/openai/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_6ED1ZQ8nrjYIOY14yqInLPZc", 'type': 'invalid_request_error', 'param': 'messages.[3].role', 'code': None}}

# %%
abot.graph.get_state(thread)

# %%
abot.graph.get_state(thread).next
# Out:
# ('llm',)

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[21], line 3
#       1 messages = [HumanMessage("Whats the weather in LA?")]
#       2 thread = {"configurable": {"thread_id": "2"}}
# ----> 3 for event in abot.graph.stream({"messages": messages}, thread):
#       4     for v in event.values():
#       5         print(v)
#
# File /usr/local/lib/python3.11/site-packages/langgraph/pregel/__init__.py:839, in Pregel.stream(self, input, config, stream_mode, output_keys, input_keys, interrupt_before, interrupt_after, debug)
#     832 done, inflight = concurrent.futures.wait(
#     833     futures,
#     834     return_when=concurrent.futures.FIRST_EXCEPTION,
#     835     timeout=self.step_timeout,
#     836 )
#     838 # panic on failure or timeout
# --> 839 _panic_or_proceed(done, inflight, step)
#     841 # combine pending writes from all tasks
#     842 pending_writes = deque[tuple[str, Any]]()
#
# File /usr/local/lib/python3.11/site-packages/langgraph/pregel/__init__.py:1342, in _panic_or_proceed(done, inflight, step)
#    1340             inflight.pop().cancel()
#    1341         # raise the exception
# -> 1342         raise exc
#    1344 if inflight:
#    1345     # if we got here means we timed out
#    1346     while inflight:
#    1347         # cancel all pending tasks
#
# File /usr/local/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /usr/local/lib/python3.11/site-packages/langgraph/pregel/retry.py:66, in run_with_retry(task, retry_policy)
#      64 task.writes.clear()
#      65 # run the task
# ---> 66 task.proc.invoke(task.input, task.config)
#      67 # if successful, end
#      68 break
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/runnables/base.py:2368, in RunnableSequence.invoke(self, input, config)
#    2366 try:
#    2367     for i, step in enumerate(self.steps):
# -> 2368         input = step.invoke(
#    2369             input,
#    2370             # mark each step as a child run
#    2371             patch_config(
#    2372                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2373             ),
#    2374         )
#    2375 # finish the root run
#    2376 except BaseException as e:
#
# File /usr/local/lib/python3.11/site-packages/langgraph/utils.py:89, in RunnableCallable.invoke(self, input, config)
#      83     context.run(var_child_runnable_config.set, config)
#      84     kwargs = (
#      85         {**self.kwargs, "config": config}
#      86         if accepts_config(self.func)
#      87         else self.kwargs
#      88     )
# ---> 89     ret = context.run(self.func, input, **kwargs)
#      90 if isinstance(ret, Runnable) and self.recurse:
#      91     return ret.invoke(input, config)
#
# Cell In[7], line 21, in Agent.call_openai(self, state)
#      19 if self.system:
#      20     messages = [SystemMessage(content=self.system)] + messages
# ---> 21 message = self.model.invoke(messages)
#      22 return {'messages': [message]}
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/runnables/base.py:4396, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4390 def invoke(
#    4391     self,
#    4392     input: Input,
#    4393     config: Optional[RunnableConfig] = None,
#    4394     **kwargs: Optional[Any],
#    4395 ) -> Output:
# -> 4396     return self.bound.invoke(
#    4397         input,
#    4398         self._merge_configs(config),
#    4399         **{**self.kwargs, **kwargs},
#    4400     )
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:170, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     159 def invoke(
#     160     self,
#     161     input: LanguageModelInput,
#    (...)
#     165     **kwargs: Any,
#     166 ) -> BaseMessage:
#     167     config = ensure_config(config)
#     168     return cast(
#     169         ChatGeneration,
# --> 170         self.generate_prompt(
#     171             [self._convert_input(input)],
#     172             stop=stop,
#     173             callbacks=config.get("callbacks"),
#     174             tags=config.get("tags"),
#     175             metadata=config.get("metadata"),
#     176             run_name=config.get("run_name"),
#     177             run_id=config.pop("run_id", None),
#     178             **kwargs,
#     179         ).generations[0][0],
#     180     ).message
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File /usr/local/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:671, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     669 else:
#     670     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 671         result = self._generate(
#     672             messages, stop=stop, run_manager=run_manager, **kwargs
#     673         )
#     674     else:
#     675         result = self._generate(messages, stop=stop, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:522, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     520 message_dicts, params = self._create_message_dicts(messages, stop)
#     521 params = {**params, **kwargs}
# --> 522 response = self.client.create(messages=message_dicts, **params)
#     523 return self._create_chat_result(response)
#
# File /usr/local/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/openai/resources/chat/completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File /usr/local/lib/python3.11/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/lib/python3.11/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File /usr/local/lib/python3.11/site-packages/openai/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_6ED1ZQ8nrjYIOY14yqInLPZc", 'type': 'invalid_request_error', 'param': 'messages.[3].role', 'code': None}}

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:47.785429+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b407-615b-8000-4b496eabd456'}})

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search_results_json',
#   'args': {'query': 'weather in Los Angeles'},
#   'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}
# {'configurable': {'thread_id': '3',
#   'thread_ts': '1f14f4f6-0edb-66f9-8002-2fff9c1b4743'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f6-0edb-66f9-8002-2fff9c1b4743'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:57.239824+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}})

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content="[{'url': 'https://www.weather25.com/north-america/usa/louisiana?page=month&month=May', 'content': '| 24 Patchy rain possible 32° /23° | 25 Sunny 32° /23° | 26 Partly cloudy 31° /24° | 27 Patchy rain possible 31° /22° | 28 Partly cloudy 32° /23° | 29 Partly cloudy 31° /23° | 30 Partly cloudy 31° /22° |\\n| 31 Partly cloudy 32° /22° |  |  |  |  |  |  | [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\\n ---  ---  --- \\n|  |  |
 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 1322, 'total_tokens': 1381, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d64f240f-99fb-4a5b-acc1-4cd4af7570db-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_lsSpmy0dI7sXbdhws8yEydtN'}])]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content="[{'url': 'https://www.weather25.com/north-america/usa/louisiana?page=month&month=May', 'content': '| 24 Patchy rain possible 32° /23° | 25 Sunny 32° /23° | 26 Partly cloudy 31° /24° | 27 Patchy rain possible 31° /22° | 28 Partly cloudy 32° /23° | 29 Partly cloudy 31° /23° | 30 Partly cloudy 31° /22° |\\n| 31 Partly cloudy 32° /22° |  |  |  |  |  |  | [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\\n ---  ---  --- \\n|  |  |  |  |  | 1 Partly cloudy 29° /19° | 2 Overcast 28° /19° |\\n| 3 Patchy rain possible 28° /20° | 4 Sunny 30° /20° | 5 Sunny 29° /20° | 6 Light rain shower 28° /21° | 7 Partly cloudy 29° /20° | 8 Partly cloudy 29° /21° | 9 Moderate or heavy rain shower 29° /21° |\\n| 10 Light rain shower 29° /21° | 11 Torrential rain shower 28° /21° | 12 Partly cloudy 28° /20° | 13 Sunny 31° /20° | 14 Sunny 30° /19° | 15 Sunny 31° /21° | 16 Sunny 30° /20° |\\n| 17 Patchy rain possible 31° /21° | 18 Sunny 33° /23° | 19 Light rain shower 32° /24° | 20 Patchy rain possible 32° /24° | 21 Light rain 33° /24° | 22 Patchy rain possible 32° /24° | 23 Thundery outbreaks possible 31° /23° | [...] Partly cloudy\\nOvercast\\nPatchy rain possible\\nSunny\\nSunny\\nLight rain shower\\nPartly cloudy\\nPartly cloudy\\nModerate or heavy rain shower\\nLight rain shower\\nTorrential rain shower\\nPartly cloudy\\nSunny\\nSunny\\nSunny\\nSunny\\nPatchy rain possible\\nSunny\\nLight rain shower\\nPatchy rain possible\\nLight rain\\nPatchy rain possible\\nThundery outbreaks possible\\nPatchy rain possible\\nSunny\\nPartly cloudy\\nPatchy rain possible\\nPartly cloudy\\nPartly cloudy\\nPartly cloudy\\nPartly cloudy\\n\\n## Explore the weather in Louisiana in other months\\n\\n## Louisiana annual weather'}, {'url': 'https://www.weather2travel.com/louisiana/may/', 'content': 'weather2travel.com - travel deals for your holiday in the sun\\nClick to search\\n\\n# Louisiana weather in May 2026\\n\\nExpect  daytime maximum temperatures of 29°C in Louisiana, USA in May based on long-term weather averages. There are 9 hours of sunshine per day on average with typically 122 mm of rainfall in the month. [...] 29°C maximum daytime temperature in May in Louisiana (New Orleans)\\n9 hours of sunshine per day (67% of daylight hours) in May in Louisiana\\n8 days with some rainfall in May in Louisiana (New Orleans)\\n19°C minimum night-time temperature in May in Louisiana (New Orleans)\\n14 hours of daylight per day in May in Louisiana (New Orleans)\\nModerate heat & humidity in May in Louisiana (New Orleans)\\n122 mm monthly rainfall in May in Louisiana (New Orleans)\\nUV (maximum) index 10 (Very High) in May in Louisiana (New Orleans)\\n\\n### More about Louisiana\\n\\nBest time to visit Louisiana\\nLouisiana weather averages by month\\nLouisiana 5-day weather forecast\\nLouisiana destinations\\nLouisiana travel deals & discounts\\n\\n### Louisiana by month\\n\\nJan\\nFeb\\nMar\\nApr\\nMay\\nJun\\nJul\\nAug\\nSep\\nOct\\nNov\\nDec [...] Goa\\n\\nIndian Ocean\\nMaldives\\nMauritius\\nSeychelles\\n\\ ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f6-0edb-66f9-8002-2fff9c1b4743'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:57.239824+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:47.785429+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b407-615b-8000-4b496eabd456'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b407-615b-8000-4b496eabd456'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-05-14T04:42:47.715657+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b404-638c-bfff-ecd1ea35538a'}})
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b404-638c-bfff-ecd1ea35538a'}}, metadata={'source': 'input', 'step': -1, 'writes': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, created_at='2026-05-14T04:42:47.714489+00:00', parent_config=None)
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:47.785429+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b407-615b-8000-4b496eabd456'}})

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherbug.com/weather-forecast/hourly/los-angeles-ca-90007?hour=4\', \'content\': "Weather Condition:Partly Cloudy\\n\\nDirection: South-Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Mostly Sunny\\n\\nDirection: Southwest\\n\\nWeather Condition:Mostly Sunny\\n\\nDirection: South-Southwest\\n\\nWeather Condition:Mostly Sunny\\n\\nDirection: South\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\n### Top stories [...] Weather Condition:Partly Cloudy\\n\\n### Top stories\\n\\n2026 AEM Atlantic Tropical Forecast\\n\\n#### Below-Normal 2026 Atlantic Hurricane Season Predicted\\n\\nThe upcoming season is expected to feature below-normal tropical activity as El Niño develops.\\n\\nSevere Thunderstorm Outlook\\n\\n#### Severe Storms Ignite Across the Northern Rockies\\n\\nToday\'s Weather Outlook\\n\\n#### Today\'s Weather Outlook\\n\\nView of Earth taken during ISS Expedition 54. (Earth Science and Remote Sensing Unit, NASA Johnson Space Center, JSC Gateway to Astronaut Photography of Earth)\\n\\n#### Atlantic and Eastern Pacific Hurricane Climatology\\n\\nDrought Monitor for May 7, 2026\\n\\n#### Unsettled Spring Pattern Leads to Mixed Drought Results [...] WeatherBug Logo\\nWeatherBug Sparky Hamburger\\nlocation\\nsearch\\nToggle Dropdown\\n\\n# Hourly Weather Forecast - Los Angeles, CA\\n\\n## Hourly forecast for Sat, May 16\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: East-Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: South\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: South-Southwest\\n\\nWeather Condition:Partly Cloudy"}, {\'url\': \'https://polymarket.com/event/highest-temperature-in-los-angeles-on-may-14-2026\', \'content\': \'Trader consensus on Polymarket tilts toward 68-69°F (36%) as the highest temperature at Los Angeles International Airport on May 14, closely trailed by 70°F or higher (31.5%) and 66-67°F (28.5%), reflecting National Weather Service guidance projecting a high near 68°F amid persistent marine layer stratus clouds and moderate onshore winds of 5-10 mph. This setup features a strong coastal temperature inversion capping mixing, limiting afternoon heating despite weak high pressure aloft; recent 00z GFS and ECMWF runs show ensemble spreads of 2-4°F, with some members forecasting earlier burn-off favoring upper-60s to low-70s if southerlies strengthen. May climatology averages 70°F at LAX, but current patterns echo typical "May Gray" variability. Watch 12z model updates and morning soundings [...] Trader consensus on Polymarket tilts toward 68-69°F (36%) as the highest temperature at Los Angeles International Airport on May 14, closely trailed by 70°F or higher (31.5%) and 66-67°F (28.5%), reflecting National Weather Service guidance projecting a high near 68°F amid persistent marine layer stratus clouds and moderate onshore winds of 5-10 mph. This setup features a strong coastal temperature inversion ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.weatherbug.com/weather-forecast/hourly/los-angeles-ca-90007?hour=4\', \'content\': "Weather Condition:Partly Cloudy\\n\\nDirection: South-Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southwest\\n\\nWeather Condition:Mostly Sunny\\n\\nDirection: Southwest\\n\\nWeather Condition:Mostly Sunny\\n\\nDirection: South-Southwest\\n\\nWeather Condition:Mostly Sunny\\n\\nDirection: South\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\n### Top stories [...] Weather Condition:Partly Cloudy\\n\\n### Top stories\\n\\n2026 AEM Atlantic Tropical Forecast\\n\\n#### Below-Normal 2026 Atlantic Hurricane Season Predicted\\n\\nThe upcoming season is expected to feature below-normal tropical activity as El Niño develops.\\n\\nSevere Thunderstorm Outlook\\n\\n#### Severe Storms Ignite Across the Northern Rockies\\n\\nToday\'s Weather Outlook\\n\\n#### Today\'s Weather Outlook\\n\\nView of Earth taken during ISS Expedition 54. (Earth Science and Remote Sensing Unit, NASA Johnson Space Center, JSC Gateway to Astronaut Photography of Earth)\\n\\n#### Atlantic and Eastern Pacific Hurricane Climatology\\n\\nDrought Monitor for May 7, 2026\\n\\n#### Unsettled Spring Pattern Leads to Mixed Drought Results [...] WeatherBug Logo\\nWeatherBug Sparky Hamburger\\nlocation\\nsearch\\nToggle Dropdown\\n\\n# Hourly Weather Forecast - Los Angeles, CA\\n\\n## Hourly forecast for Sat, May 16\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Partly Cloudy\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: East-Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: South-Southeast\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: South\\n\\nWeather Condition:Mostly Cloudy\\n\\nDirection: South-Southwest\\n\\nWeather Condition:Partly Cloudy"}, {\'url\': \'https://polymarket.com/event/highest-temperature-in-los-angeles-on-may-14-2026\', \'content\': \'Trader consensus on Polymarket tilts toward 68-69°F (36%) as the highest temperature at Los Angeles International Airport on May 14, closely trailed by 70°F or higher (31.5%) and 66-67°F (28.5%), reflecting National Weather Service guidance projecting a high near 68°F amid persistent marine la ...
# {'messages': [AIMessage(content='The weather in Los Angeles is partly cloudy with temperatures ranging between 66-70°F. The direction of the wind varies from South-Southwest to Southeast.', response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 1198, 'total_tokens': 1231, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c11604b5-423a-47b1-9a56-26dcb45ee4f8-0')]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:47.785429+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b407-615b-8000-4b496eabd456'}})

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/new-orleans/70112/may-weather/348585\', \'content\': "### Winter Center\\n\\n## Monthly\\n\\n## May\\n\\n## 2026\\n\\n## 10-Day\\n\\nPartly sunny\\nMostly sunny\\nMostly sunny\\nSun and some clouds\\nHumid with clouds and sun\\nHumid; a strong a.m. t-storm\\nHumid with a few showers\\nHumid with a few showers\\nCloudy, showers around; humid\\nCloudy and humid with showers\\nPartly sunny and humid\\nHumid with sunshine\\nHumid with some sun\\nCloudy and humid\\nHumid with some sun\\nHumid with clouds and sun\\nHumid with some sun\\nAn afternoon thunderstorm\\nA shower and thunderstorm\\nMostly cloudy and humid\\nCloudy and humid\\nCloudy and humid\\nA thunderstorm in spots\\nA shower and thunderstorm\\nAn afternoon thunderstorm\\n\\n## Temperature Graph\\n\\n## May Weather in New Orleans\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### June 2026\\n\\n### July 2026\\n\\n### August 2026\\n\\n## Around the Globe\\n\\nAround the Glob
, {\'url\': \'https://www.accuweather.com/en/us/los-angeles-zoo/90027/may-weather/32793_poi\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## May\\n\\n## 2026\\n\\n## 10-Day\\n\\nDecreasing clouds\\nPartly sunny\\nMostly sunny\\nMostly sunny and nice\\nMostly sunny and nice\\nPartly sunny and pleasant\\nPleasant with plenty of sun\\nPlenty of sunshine\\nMostly sunny\\nVariable cloudiness\\nMostly sunny\\nSunny\\nMostly sunny\\nPartial sunshine\\nMostly cloudy\\nSunshine and a few clouds\\nPartly sunny\\nMostly sunny\\nPartly sunny\\nSunny\\nSunny to partly cloudy\\nMostly sunny\\nPlenty of sunshine\\nPlenty of sunshine\\nSome sun\\n\ ...
# {'messages': [AIMessage(content='I found information about the current weather in Los Angeles. The weather in Los Angeles Zoo is currently described as "Mostly sunny and nice". Would you like more details or information about the temperature?', response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 1188, 'total_tokens': 1228, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-90080335-bae3-4038-b0d3-72b25e5688d8-0')]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b4b1-670c-8001-37493e6e2608'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-05-14T04:42:47.785429+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f14f4f5-b407-615b-8000-4b496eabd456'}})

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search_results_json",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config, 
    state_update, 
    as_node="action")

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='74984865-facb-4516-a94b-1ef09bd97436'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-8c73e353-fddc-443e-abcc-3aa2737087cd-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='54 degree celcius', name='tavily_search_results_json', id='b1c1b6f6-1a93-4f04-8a8a-cfef02f5a73c', tool_call_id='call_6ED1ZQ8nrjYIOY14yqInLPZc'), AIMessage(content='The current weather in Los Angeles is 54 degrees Celsius.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-52b45de3-a76f-4824-bfd8-98b9e87dcfc9-0')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is 54 degrees Celsius.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-52b45de3-a76f-4824-bfd8-98b9e87dcfc9-0')]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langgraph.checkpoint.sqlite import SqliteSaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2", 
                              should_continue, 
                              {True: "Node1", False: END})
builder.set_entry_point("Node1")

# %%
memory = SqliteSaver.from_conn_string(":memory:")
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624e-67da-8004-b91baf01c929'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:32.833671+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}})

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624e-67da-8004-b91baf01c929'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:32.833671+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:32.832569+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6249-64a3-8002-10038c71508e'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6249-64a3-8002-10038c71508e'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:32.831537+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:32.828938+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-05-14T04:43:32.826988+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623b-6497-bfff-5426dd2629b1'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623b-6497-bfff-5426dd2629b1'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2026-05-14T04:43:32.825808+00:00', parent_config=None)

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624e-67da-8004-b91baf01c929'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6249-64a3-8002-10038c71508e'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}} 1
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}} 0
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623b-6497-bfff-5426dd2629b1'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:32.828938+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}})

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4f6-686c-8004-6642653b0423'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4f3-6073-8003-12399abb772d'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4ed-669a-8002-be0acee28779'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624e-67da-8004-b91baf01c929'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6249-64a3-8002-10038c71508e'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}} 1
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}} 0
# {'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623b-6497-bfff-5426dd2629b1'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4f6-686c-8004-6642653b0423'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:44.856267+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4f3-6073-8003-12399abb772d'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4f3-6073-8003-12399abb772d'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:44.854832+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4ed-669a-8002-be0acee28779'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-d4ed-669a-8002-be0acee28779'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:44.852519+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624e-67da-8004-b91baf01c929'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:32.833671+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-624b-6cab-8003-3c7f85e39977'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:32.832569+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6249-64a3-8002-10038c71508e'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6249-64a3-8002-10038c71508e'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:32.831537+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-6242-6f04-8001-cdce83b6f63d'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:32.828938+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623e-62a0-8000-d89cdaa36a40'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-05-14T04:43:32.826988+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623b-6497-bfff-5426dd2629b1'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f14f4f7-623b-6497-bfff-5426dd2629b1'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2026-05-14T04:43:32.825808+00:00', parent_config=None)

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
from IPython.display import Image

Image(graph.get_graph().draw_png())

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}} 4
# {'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fe-6db9-8003-70dc3e87313c'}} 3
# {'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fc-6803-8002-202a2629a34c'}} 2
# {'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f8-662e-8001-bda6fce09f4f'}} 1
# {'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f5-6940-8000-7def394ca566'}} 0
# {'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f2-6518-bfff-cb4c5b5bc15b'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f8-662e-8001-bda6fce09f4f'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:46.744459+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f5-6940-8000-7def394ca566'}})

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f8-662e-8001-bda6fce09f4f'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:46.744459+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f5-6940-8000-7def394ca566'}})

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'thread_ts': '1f14f4f8-05d7-626e-8005-88703e639156'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-05d7-626e-8005-88703e639156'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-05-14T04:43:49.981437+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:46.748316+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fe-6db9-8003-70dc3e87313c'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fe-6db9-8003-70dc3e87313c'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:46.747120+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fc-6803-8002-202a2629a34c'}})

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'thread_ts': '1f14f4f8-31f5-63db-8006-7943f104ba06'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-31f5-63db-8006-7943f104ba06'}}, metadata={'source': 'update', 'step': 6, 'writes': {'Node1': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-05-14T04:43:54.607493+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-05d7-626e-8005-88703e639156'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-05d7-626e-8005-88703e639156'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-05-14T04:43:49.981437+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:46.748316+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fe-6db9-8003-70dc3e87313c'}})

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37b1-6379-800b-e8efb8f80bcc'}}, metadata={'source': 'loop', 'step': 11, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:55.208780+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37ae-623b-800a-5ada457ffc4f'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37ae-623b-800a-5ada457ffc4f'}}, metadata={'source': 'loop', 'step': 10, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:55.207523+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37ac-62c7-8009-e918980a07e3'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37ac-62c7-8009-e918980a07e3'}}, metadata={'source': 'loop', 'step': 9, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:55.206713+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37a8-69ae-8008-8824d007a399'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37a8-69ae-8008-8824d007a399'}}, metadata={'source': 'loop', 'step': 8, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:55.205249+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37a4-659c-8007-cd670d1e87b5'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-37a4-659c-8007-cd670d1e87b5'}}, metadata={'source': 'loop', 'step': 7, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:55.203504+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-31f5-63db-8006-7943f104ba06'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-31f5-63db-8006-7943f104ba06'}}, metadata={'source': 'update', 'step': 6, 'writes': {'Node1': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-05-14T04:43:54.607493+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-05d7-626e-8005-88703e639156'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f8-05d7-626e-8005-88703e639156'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-05-14T04:43:49.981437+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e701-6cbf-8004-c91fb40dd4de'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:46.748316+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fe-6db9-8003-70dc3e87313c'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fe-6db9-8003-70dc3e87313c'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:46.747120+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fc-6803-8002-202a2629a34c'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6fc-6803-8002-202a2629a34c'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-05-14T04:43:46.746152+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f8-662e-8001-bda6fce09f4f'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f8-662e-8001-bda6fce09f4f'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-05-14T04:43:46.744459+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f5-6940-8000-7def394ca566'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f5-6940-8000-7def394ca566'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-05-14T04:43:46.743318+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f2-6518-bfff-cb4c5b5bc15b'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f14f4f7-e6f2-6518-bfff-cb4c5b5bc15b'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2026-05-14T04:43:46.741981+00:00', parent_config=None)

# %% [markdown]
# Continue to experiment!
